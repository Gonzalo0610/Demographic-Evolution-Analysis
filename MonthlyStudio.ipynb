# %%
import requests
import datetime
import pandas as pd

# %%
bornmonth=pd.read_csv("Movimiento Natural de la Población Nacimientos.csv", sep=';', decimal=',')

# %%
bornmonth.columns
# Out:
# Index(['Comunidades y Ciudades Autónomas', 'Periodo', 'Total'], dtype='object')

# %%
bornmonth.dtypes
# Out:
# Comunidades y Ciudades Autónomas    object
# Periodo                             object
# Total                               object
# dtype: object

# %%
bornmonth['Total']=bornmonth['Total'].str.replace(".", "")
# Out:
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\4275167329.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bornmonth['Total']=bornmonth['Total'].str.replace(".", "")

# %%
bornmonth.sample(20)
# Out:
#       Comunidades y Ciudades Autónomas  Periodo Total
# 3396                      06 Cantabria  2020M12   238
# 10416                         18 Ceuta  1999M12    76
# 2870                       05 Canarias  2017M10  1518
# 4773           08 Castilla - La Mancha  2000M03  1452
# 4853           08 Castilla - La Mancha  1993M07  1628
# 5730           10 Comunitat Valenciana  2014M06  3462
# 9802                      17 Rioja, La  2004M02   258
# 6939                        12 Galicia  2007M09  1799
# 11150                       19 Melilla  1985M10    84
# 9712                      17 Rioja, La  2011M08   296
# 3576                      06 Cantabria  2005M12   487
# 2705                 04 Balears, Illes  1984M07   715
# 5166                       09 Cataluña  2014M06  5907
# 11179                       19 Melilla  1983M05    22
# 9102                     16 País Vasco  2015M06  1512
# 8900    15 Navarra, Comunidad Foral de  1985M04   458
# ...

# %%
bornmonth['Total']=bornmonth['Total'].astype(int)

# %%
bornmonth['Comunidades y Ciudades Autónomas'].unique()
# Out:
# array(['Total', '01 Andalucía', '02 Aragón', '03 Asturias, Principado de',
#        '04 Balears, Illes', '05 Canarias', '06 Cantabria',
#        '07 Castilla y León', '08 Castilla - La Mancha', '09 Cataluña',
#        '10 Comunitat Valenciana', '11 Extremadura', '12 Galicia',
#        '13 Madrid, Comunidad de', '14 Murcia, Región de',
#        '15 Navarra, Comunidad Foral de', '16 País Vasco', '17 Rioja, La',
#        '18 Ceuta', '19 Melilla', 'No residente'], dtype=object)

# %%
bornmonth['Periodo'] = bornmonth['Periodo'].str[-2:]

# %%
bornmonth.head(20)
# Out:
#    Comunidades y Ciudades Autónomas Periodo  Total
# 0                             Total      12  28574
# 1                             Total      11  28452
# 2                             Total      10  30135
# 3                             Total      09  30229
# 4                             Total      08  29640
# 5                             Total      07  30538
# 6                             Total      06  27546
# 7                             Total      05  27616
# 8                             Total      04  27315
# 9                             Total      03  29020
# 10                            Total      02  24413
# 11                            Total      01  23902
# 12                            Total      12  23490
# 13                            Total      11  26765
# 14                            Total      10  30296
# 15                            Total      09  30318
# 16                            Total      08  29647
# ...

# %%
#bornmonth['Total'] = bornmonth['Total'].astype(int).astype(str)
#bornmonth['Total'] = bornmonth['Total'].str.replace('.000', '', regex=False)

# %%
(bornmonth[bornmonth['Comunidades y Ciudades Autónomas']=='19 Melilla'])["Total"].min()
# Out:
# 22

# %%
bornmonth.sample(20)
# Out:
#       Comunidades y Ciudades Autónomas Periodo  Total
# 3498                      06 Cantabria      06    409
# 8685    15 Navarra, Comunidad Foral de      03    533
# 11518                     No residente      02     82
# 10773                       19 Melilla      03     97
# 4216                07 Castilla y León      08   1520
# 6377                    11 Extremadura      07    874
# 6581                    11 Extremadura      07   1100
# 6164           10 Comunitat Valenciana      04   5741
# 677                       01 Andalucía      07   7174
# 7642           13 Madrid, Comunidad de      02   3634
# 3646                      06 Cantabria      02    311
# 920                       01 Andalucía      04   6965
# 350                              Total      10  33828
# 10088                     17 Rioja, La      04    316
# 2411                 04 Balears, Illes      01   1065
# 5829           10 Comunitat Valenciana      03   4473
# ...

# %%
bornmonth.dtypes
# Out:
# Comunidades y Ciudades Autónomas    object
# Periodo                             object
# Total                                int32
# dtype: object

# %%
bornmonth.sample(20)
# Out:
#       Comunidades y Ciudades Autónomas Periodo  Total
# 8496    15 Navarra, Comunidad Foral de      12    410
# 5946           10 Comunitat Valenciana      06   2870
# 4068                07 Castilla y León      12   1598
# 1110                      01 Andalucía      06  10358
# 3916                      06 Cantabria      08    813
# 1463                         02 Aragón      01    804
# 9613                      17 Rioja, La      11    203
# 4729           08 Castilla - La Mancha      11   1470
# 10578                         18 Ceuta      06     89
# 6431                    11 Extremadura      01    877
# 2931                       05 Canarias      09   1471
# 2194        03 Asturias, Principado de      02   1126
# 4921           08 Castilla - La Mancha      11   1468
# 8039              14 Murcia, Región de      01   1545
# 6134           10 Comunitat Valenciana      10   5101
# 324                              Total      12  30263
# ...

# %%
totborn=bornmonth[bornmonth['Comunidades y Ciudades Autónomas']=="Total"]

# %%
totborn.drop('Comunidades y Ciudades Autónomas', axis=1, inplace=True)
# Out:
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\3060777255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totborn.drop('Comunidades y Ciudades Autónomas', axis=1, inplace=True)

# %%
totborn.sample()
# Out:
#     Periodo  Total
# 216      12  36738

# %%
totborn.sample()
# Out:
#     Periodo  Total
# 497      07  49741

# %%
grouped_df = totborn.groupby(totborn['Periodo'])['Periodo','Total'].sum()
# Out:
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\1869604183.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_df = totborn.groupby(totborn['Periodo'])['Periodo','Total'].sum()
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\1869604183.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = totborn.groupby(totborn['Periodo'])['Periodo','Total'].sum()

# %%
grouped_df.head(12)
# Out:
#            Total
# Periodo
# 01       1772130
# 02       1615716
# 03       1790016
# 04       1749595
# 05       1838647
# 06       1744676
# 07       1833934
# 08       1799173
# 09       1819867
# 10       1822393
# 11       1717620
# 12       1735040

# %%
type(grouped_df)
# Out:
# pandas.core.frame.DataFrame

# %%
month_days = pd.Series({
    '01': 31,
    '02': 28.25,
    '03': 31,
    '04': 30,
    '05': 31,
    '06': 30,
    '07': 31,
    '08': 31,
    '09': 30,
    '10': 31,
    '11': 30,
    '12': 31
})

# %%
grouped_df['Total'] = grouped_df.apply(lambda x: x['Total'] / month_days[x.name], axis=1)

# %%
grouped_df
# Out:
#                 Total
# Periodo
# 01       57165.483871
# 02       57193.486726
# 03       57742.451613
# 04       58319.833333
# 05       59311.193548
# 06       58155.866667
# 07       59159.161290
# 08       58037.838710
# 09       60662.233333
# 10       58786.870968
# 11       57254.000000
# 12       55969.032258

# %%
monthrate=grouped_df.copy()

# %%
monthrate['Total'] = monthrate.apply(lambda x: x['Total'] / monthrate.Total.max(), axis=1)

# %%
monthrate
# Out:
#             Total
# Periodo
# 01       0.942357
# 02       0.942819
# 03       0.951868
# 04       0.961386
# 05       0.977728
# 06       0.958683
# 07       0.975222
# 08       0.956738
# 09       1.000000
# 10       0.969085
# 11       0.943816
# 12       0.922634

# %%
ccaa=['01 Andalucía', '02 Aragón', '03 Asturias, Principado de',
       '04 Balears, Illes','06 Cantabria',
       '07 Castilla y León', '08 Castilla - La Mancha', '09 Cataluña',
       '10 Comunitat Valenciana', '11 Extremadura', '12 Galicia',
       '13 Madrid, Comunidad de', '14 Murcia, Región de',
       '15 Navarra, Comunidad Foral de', '16 País Vasco', '17 Rioja, La',
       ]

# %%
len(ccaa)
# Out:
# 16

# %%
bornmonth.sample()
# Out:
#      Comunidades y Ciudades Autónomas Periodo  Total
# 4771          08 Castilla - La Mancha      05  1.508

# %%
ccaamonth=bornmonth.copy()

# %%
ccaamonth=bornmonth.groupby(["Periodo", "Comunidades y Ciudades Autónomas"])["Total"].sum().reset_index()

# %%
ccaamonth.head(30)
# Out:
#    Periodo Comunidades y Ciudades Autónomas    Total
# 0       01                     01 Andalucía   361299
# 1       01                        02 Aragón    45233
# 2       01       03 Asturias, Principado de    34304
# 3       01                04 Balears, Illes    39334
# 4       01                      05 Canarias    77302
# 5       01                     06 Cantabria    20386
# 6       01               07 Castilla y León    83368
# 7       01          08 Castilla - La Mancha    74614
# 8       01                      09 Cataluña   279596
# 9       01          10 Comunitat Valenciana   184454
# 10      01                   11 Extremadura    45386
# 11      01                       12 Galicia    96967
# 12      01          13 Madrid, Comunidad de   240539
# 13      01             14 Murcia, Región de    62522
# 14      01   15 Navarra, Comunidad Foral de    22859
# 15      01                    16 País Vasco    81269
# 16      01                     17 Rioja, La    10652
# ...

# %%
prueba=ccaamonth.copy()

# %%
prueba=prueba.pivot_table(values="Total", index=prueba.Periodo, columns='Comunidades y Ciudades Autónomas')

# %%
prueba.sample()
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 04                                      344421      45537
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 04                                                     34831
#
# Comunidades y Ciudades Autónomas  04 Balears, Illes  05 Canarias  \
# Periodo
# 04                                            36665        71917
#
# Comunidades y Ciudades Autónomas  06 Cantabria  07 Castilla y León  \
# Periodo
# 04                                       20330               88842
#
# Comunidades y Ciudades Autónomas  08 Castilla - La Mancha  09 Cataluña  \
# Periodo
# 04                                                  77397       269975
#
# Comunidades y Ciudades Autónomas  10 Comunitat Valenciana  ...  12 Galicia  \
# Periodo                                                    ...
# 04                                                 175637  ...       96220
#
# ...

# %%
prueba.drop(["05 Canarias", '18 Ceuta', '19 Melilla', 'No residente', 'Total'], axis=1, inplace=True)

# %%
prueba.sample()
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 12                                      356907      44098
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 12                                                     33606
#
# Comunidades y Ciudades Autónomas  04 Balears, Illes  06 Cantabria  \
# Periodo
# 12                                            38622         20199
#
# Comunidades y Ciudades Autónomas  07 Castilla y León  08 Castilla - La Mancha  \
# Periodo
# 12                                             81041                    72521
#
# Comunidades y Ciudades Autónomas  09 Cataluña  10 Comunitat Valenciana  \
# Periodo
# 12                                     270362                   181982
#
# Comunidades y Ciudades Autónomas  11 Extremadura  12 Galicia  \
# Periodo
# 12                                         43936       93948
#
# Comunidades y Ciudades Autónomas  13 Madrid, Comunidad de  \
# Periodo
# ...

# %%
prueba
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                      361299      45233
# 02                                      326770      41992
# 03                                      358154      46275
# 04                                      344421      45537
# 05                                      357472      48572
# 06                                      341884      46356
# 07                                      367884      48792
# 08                                      366530      46873
# 09                                      375121      46515
# 10                                      374852      46132
# 11                                      353507      43901
# 12                                      356907      44098
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                     34304
# 02                                                     31605
# ...

# %%
for i in prueba:
    prueba[i] = prueba.apply(lambda x: x[i] / month_days[x.name], axis=1)

# %%
prueba
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía    02 Aragón  \
# Periodo
# 01                                11654.806452  1459.129032
# 02                                11567.079646  1486.442478
# 03                                11553.354839  1492.741935
# 04                                11480.700000  1517.900000
# 05                                11531.354839  1566.838710
# 06                                11396.133333  1545.200000
# 07                                11867.225806  1573.935484
# 08                                11823.548387  1512.032258
# 09                                12504.033333  1550.500000
# 10                                12092.000000  1488.129032
# 11                                11783.566667  1463.366667
# 12                                11513.129032  1422.516129
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                               1106.580645
# ...

# %%
final=prueba.copy()

# %%
final
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía    02 Aragón  \
# Periodo
# 01                                11654.806452  1459.129032
# 02                                11567.079646  1486.442478
# 03                                11553.354839  1492.741935
# 04                                11480.700000  1517.900000
# 05                                11531.354839  1566.838710
# 06                                11396.133333  1545.200000
# 07                                11867.225806  1573.935484
# 08                                11823.548387  1512.032258
# 09                                12504.033333  1550.500000
# 10                                12092.000000  1488.129032
# 11                                11783.566667  1463.366667
# 12                                11513.129032  1422.516129
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                               1106.580645
# ...

# %%
for i in final: 
   final[i] = final.apply(lambda x: x[i] / final[i].max(), axis=1)

# %%
final
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                    0.932084   0.927058
# 02                                    0.925068   0.944411
# 03                                    0.923970   0.948414
# 04                                    0.918160   0.964398
# 05                                    0.922211   0.995491
# 06                                    0.911397   0.981743
# 07                                    0.949072   1.000000
# 08                                    0.945579   0.960670
# 09                                    1.000000   0.985110
# 10                                    0.967048   0.945483
# 11                                    0.942381   0.929750
# 12                                    0.920753   0.903796
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                  0.935326
# 02                                                  0.945621
# ...

# %%
superfinal=final.copy()

# %%
superfinal["Total"]=monthrate["Total"]

# %%
superfinal
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                    0.932084   0.927058
# 02                                    0.925068   0.944411
# 03                                    0.923970   0.948414
# 04                                    0.918160   0.964398
# 05                                    0.922211   0.995491
# 06                                    0.911397   0.981743
# 07                                    0.949072   1.000000
# 08                                    0.945579   0.960670
# 09                                    1.000000   0.985110
# 10                                    0.967048   0.945483
# 11                                    0.942381   0.929750
# 12                                    0.920753   0.903796
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                  0.935326
# 02                                                  0.945621
# ...

# %%
for i in superfinal: 
   superfinal[i] = superfinal.apply(lambda x: x[i] - x["Total"], axis=1)

# %%
superfinal
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                   -0.010273  -0.015299
# 02                                   -0.017751   0.001593
# 03                                   -0.027898  -0.003455
# 04                                   -0.043226   0.003012
# 05                                   -0.055518   0.017763
# 06                                   -0.047287   0.023060
# 07                                   -0.026150   0.024778
# 08                                   -0.011159   0.003932
# 09                                    0.000000  -0.014890
# 10                                   -0.002037  -0.023602
# 11                                   -0.001435  -0.014066
# 12                                   -0.001881  -0.018838
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                 -0.007032
# 02                                                  0.002802
# ...

# %%
superfinal.describe()
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# count                                12.000000  12.000000
# mean                                 -0.020385  -0.001334
# std                                   0.019581   0.016636
# min                                  -0.055518  -0.023602
# 25%                                  -0.031730  -0.014992
# 50%                                  -0.014455  -0.000931
# 75%                                  -0.001998   0.007390
# max                                   0.000000   0.024778
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# count                                              12.000000
# mean                                               -0.002842
# std                                                 0.016127
# min                                                -0.034229
# 25%                                                -0.008921
# 50%                                                -0.003568
# ...

# %%
marriage=pd.read_csv("Marriage.csv", sep=';', decimal=',')

# %%
marriage['Total']=marriage['Total'].str.replace(".", "")
# Out:
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\1582035451.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   marriage['Total']=marriage['Total'].str.replace(".", "")

# %%
df1 = marriage[marriage.isna().any(axis=1)]
df1
# Out:
#       Comunidades y Ciudades Autónomas  Periodo Total
# 10172                         18 Ceuta  2020M04   NaN
# 10736                       19 Melilla  2020M04   NaN

# %%
marriage.dropna(inplace=True)

# %%
marriage['Total']=marriage['Total'].astype(int)

# %%
marriage['Periodo'] = marriage['Periodo'].str[-2:]

# %%
totmar=marriage[marriage['Comunidades y Ciudades Autónomas']=="Total"]

# %%
totmar.drop('Comunidades y Ciudades Autónomas', axis=1, inplace=True)
# Out:
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\74481156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totmar.drop('Comunidades y Ciudades Autónomas', axis=1, inplace=True)

# %%
grouped_mar = totmar.groupby(totmar['Periodo'])['Periodo','Total'].sum()
# Out:
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\2422675130.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_mar = totmar.groupby(totmar['Periodo'])['Periodo','Total'].sum()
# C:\Users\gqsal\AppData\Local\Temp\ipykernel_21180\2422675130.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_mar = totmar.groupby(totmar['Periodo'])['Periodo','Total'].sum()

# %%
grouped_mar['Total'] = grouped_mar.apply(lambda x: x['Total'] / month_days[x.name], axis=1)

# %%
grouped_mar
# Out:
#                 Total
# Periodo
# 01       11556.258065
# 02       13096.141593
# 03       19194.064516
# 04       22761.733333
# 05       27628.903226
# 06       34264.666667
# 07       36660.806452
# 08       30912.258065
# 09       42062.166667
# 10       32157.419355
# 11       17107.266667
# 12       19024.129032

# %%
marrate=grouped_mar.copy()

# %%
marrate['Total'] = marrate.apply(lambda x: x['Total'] / marrate.Total.max(), axis=1)

# %%
marrate
# Out:
#             Total
# Periodo
# 01       0.274742
# 02       0.311352
# 03       0.456326
# 04       0.541145
# 05       0.656859
# 06       0.814620
# 07       0.871586
# 08       0.734918
# 09       1.000000
# 10       0.764521
# 11       0.406714
# 12       0.452286

# %%
marccaa=marriage.groupby(["Periodo", "Comunidades y Ciudades Autónomas"])["Total"].sum().reset_index()

# %%
marccaa
# Out:
#     Periodo Comunidades y Ciudades Autónomas   Total
# 0        01                     01 Andalucía   70254
# 1        01                        02 Aragón    7141
# 2        01       03 Asturias, Principado de    9792
# 3        01                04 Balears, Illes   10064
# 4        01                      05 Canarias   18293
# ..      ...                              ...     ...
# 247      12                     17 Rioja, La    2530
# 248      12                         18 Ceuta    1267
# 249      12                       19 Melilla    1366
# 250      12                     No residente    4383
# 251      12                            Total  589748
#
# [252 rows x 3 columns]

# %%
marccaa=marccaa.pivot_table(values="Total", index=marccaa.Periodo, columns='Comunidades y Ciudades Autónomas')

# %%
marccaa
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                       70254       7141
# 02                                       71536       7937
# 03                                      121559      14970
# 04                                      133137      19033
# 05                                      140141      26496
# 06                                      184155      31453
# 07                                      184240      31982
# 08                                      196239      27435
# 09                                      230236      43080
# 10                                      193460      28271
# 11                                       88789      13394
# 12                                      134715      11244
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                      9792
# 02                                                     10003
# ...

# %%
marccaa.drop(["05 Canarias", '18 Ceuta', '19 Melilla', 'No residente', 'Total'], axis=1, inplace=True)

# %%
for i in marccaa:
    marccaa[i] = marccaa.apply(lambda x: x[i] / month_days[x.name], axis=1)

# %%
final2=marccaa.copy()

# %%
for i in final2: 
   final2[i] = final2.apply(lambda x: x[i] / final2[i].max(), axis=1)

# %%
final2
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                    0.295296   0.160414
# 02                                    0.329955   0.195652
# 03                                    0.510944   0.336284
# 04                                    0.578263   0.441806
# 05                                    0.589049   0.595202
# 06                                    0.799853   0.730107
# 07                                    0.774409   0.718438
# 08                                    0.824844   0.616295
# 09                                    1.000000   1.000000
# 10                                    0.813163   0.635075
# 11                                    0.385643   0.310910
# 12                                    0.566242   0.252583
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                  0.309263
# 02                                                  0.346681
# ...

# %%
superfinal2=final2.copy()

# %%
superfinal2['Total']=marrate['Total']

# %%
for i in superfinal2: 
   superfinal2[i] = superfinal2.apply(lambda x: x[i] - x["Total"], axis=1)

# %%
superfinal2
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# Periodo
# 01                                    0.020554  -0.114328
# 02                                    0.018603  -0.115700
# 03                                    0.054618  -0.120043
# 04                                    0.037118  -0.099339
# 05                                   -0.067810  -0.061657
# 06                                   -0.014766  -0.084513
# 07                                   -0.097178  -0.153148
# 08                                    0.089925  -0.118623
# 09                                    0.000000   0.000000
# 10                                    0.048642  -0.129446
# 11                                   -0.021070  -0.095804
# 12                                    0.113956  -0.199703
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# Periodo
# 01                                                  0.034521
# 02                                                  0.035329
# ...

# %%
superfinal2.describe()
# Out:
# Comunidades y Ciudades Autónomas  01 Andalucía  02 Aragón  \
# count                                12.000000  12.000000
# mean                                  0.015216  -0.107692
# std                                   0.060673   0.048478
# min                                  -0.097178  -0.199703
# 25%                                  -0.016342  -0.122393
# 50%                                   0.019578  -0.115014
# 75%                                   0.050136  -0.092981
# max                                   0.113956   0.000000
#
# Comunidades y Ciudades Autónomas  03 Asturias, Principado de  \
# count                                              12.000000
# mean                                                0.024347
# std                                                 0.041658
# min                                                -0.036903
# 25%                                                -0.001828
# 50%                                                 0.022617
# ...
